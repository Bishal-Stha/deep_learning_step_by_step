# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
hours_studied = np.array([2.5, 4.0, 6.0, 8.5])
marks_obtained = np.array([45.75, 75.0,92.5,98.5])

plt.plot(hours_studied,marks_obtained)
plt.show()

# %% [markdown]
# Perceptron:
#
# Input (X)
# Weights (W)
# Biases (b)
#
# Z = X * W +b or W * X<sup>T</sup>

# %%
x = np.array([1,2,3])
y = np.array([3,2,1])
np.dot(x,y)
# Out:
# np.int64(10)

# %%
size = x.shape
weights = np.random.randn(size[0])
bias = np.random.randn(1)
weights, bias

# size[0]
# Out:
# (array([0.27351475, 0.18030224, 0.08734047]), array([0.85189402]))

# %%
z = sum(np.dot(weights,x.T)+bias)
z
# Out:
# np.float64(1.7480346503367987)

# %%
np.tanh(z)
# Out:
# np.float64(0.9411514436170898)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=100, n_features=2, n_informative=2, n_redundant=0)
X.shape, y.shape
# Out:
# ((100, 2), (100,))

# %%
X
# Out:
# array([[ 1.5884433 ,  0.09364763],
#        [ 0.50471449,  1.91936694],
#        [-1.5934924 , -0.17663968],
#        [ 1.32748621, -0.87010302],
#        [-0.74613111,  0.18044497],
#        [ 1.59568491, -0.52073406],
#        [ 2.24931103, -0.96971958],
#        [ 0.60279175,  1.63455219],
#        [-1.69111245, -1.01268391],
#        [ 0.52434545, -1.01144326],
#        [-1.58721199, -0.78579968],
#        [-0.2449995 ,  1.4536548 ],
#        [-1.79965107, -0.54925134],
#        [ 1.30549953, -0.98976439],
#        [ 1.11505299,  0.80828176],
#        [ 0.36893257,  2.10434958],
#        [ 0.19224291, -2.30178786],
#        [ 0.35668281, -0.79990084],
#        [ 1.40729555, -1.08130631],
#        [ 1.49562629,  0.03346623],
#        [-1.25075825,  0.63321827],
#        [-0.75143978,  2.79153401],
#        [ 1.62373285, -0.5906301 ],
#        [ 0.99271153,  0.73785041],
#        [-1.45802011, -1.21558025],
#        [-0.51842515,  0.25364614],
#        [ 0.11985846, -1.38557937],
# ...

# %%
plt.scatter(X[:,0],X[:,1],c=y, cmap='winter',s=100)

# %%
# np.insert(X,2,2,axis=0) # X is array, 0 is which row in the data, 2 is value, axis=1 is column

# %%
def step(z):
    return 1 if z>0 else 0

# %%
x_vals = np.arange(-5, 5, 0.25)
plt.plot(x_vals, np.vectorize(step)(x_vals))

# %%
def RELU(x):
    return 0 if x <0 else x

# %%
plt.plot(x_vals, np.vectorize(RELU)(x_vals))

# %%
def Perceptron(X,y):
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.01
    epoches = 1000

    for i in range(epoches):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr * (y[j] - y_hat)*X[j]
    return weights[0], weights[1:]

# %%
intercept_, coef_ = Perceptron(X,y)
intercept_, coef_
# Out:
# (np.float64(-0.020000000000000753), array([0.36573202, 0.04481927]))

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])
m,b
# Out:
# (np.float64(-8.160150709190402), np.float64(0.44623660348156236))

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
